# %%
import requests
from bs4 import BeautifulSoup
from requests.exceptions import HTTPError
from urllib3.exceptions import MaxRetryError

# %%
clientIdSecretIdIn64base= '' #here the clientid:secretid in base 64

# %%
urlBase = 'https://api.spotify.com/v1'
endpArtist ='/artists/{id}' 
idArtist = '1Xyo4u8uXC1ZmMpatF05PJ'

# %%
urlBaseArtist = urlBase+endpArtist.format(id=idArtist)
# Out:
# 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'

# %%
def visit(url,header):
    "method who returnd JSon object"
    try:
        response = requests.get(url,headers=header)
        print("EL status code: ", response.status_code)
        response.raise_for_status()  # arroja si la solicitud no se concluye correctamente
        return response
    
    except HTTPError as http_err:
        print(f'HTTP error occurred: {http_err}')  # Python 3.6
    except MaxRetryError as Max_err:
        print(f'HTTP error MaxEntry ocurred: {Max_err}')  # Python 3.6
    except Exception as err:
        print(f'Other error occurred: {err}')  # Python 3.6
    return response

# %%
tokenUrl = 'https://accounts.spotify.com/api/token'

# %%
params = {'grant_type':'client_credentials'}

# %%
headers = {'Authorization': 'Basic Mjc0OWM5NjA3MzE5NDcwMWIxNjJmNWI1MTA4MTEyYzk6NjgwODNiM2I4MDU1NDZiZmI2ZTM4YWQzMDBkZWM4MGU='}

# %%
response = requests.post(tokenUrl,data=params, headers=headers)
response.status_code
# Out:
# 400

# %%
token = response.json()['access_token']

# %%
header = {'Authorization': 'Bearer {}'.format(token)}

# %%
response = visit(url,header)
# Out:
# EL status code:  200

# %%
urlSearchBase = ' https://api.spotify.com/v1/search'

# %%
searchParams = {'q':"the Weeknd",
                'type':'artist',
               'market':'AR'}

# %%
busqueda = requests.get(urlSearchBase,headers=header,params=searchParams)

# %%
import pandas as pd

# %%
df = pd.DataFrame(busqueda.json()['artists']['items'])
df.head()
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/1...
# 1  {'spotify': 'https://open.spotify.com/artist/4...
#
#                            followers  \
# 0  {'href': None, 'total': 24240432}
# 1        {'href': None, 'total': 55}
#
#                                            genres  \
# 0  [canadian contemporary r&b, canadian pop, pop]
# 1                                              []
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/1Xyo4u8uXC1...  1Xyo4u8uXC1ZmMpatF05PJ
# 1  https://api.spotify.com/v1/artists/4hX2FJqqKfT...  4hX2FJqqKfTHzSL5kQYa0O
#
#                                               images          name  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...    The Weeknd
# 1                                                 []  The Weeknd´s
#
#    popularity    type                                    uri
# ...

# %%
popuparArtistRow = df.sort_values(by='popularity',ascending=False).iloc[0]

# %%
def get_token(client_id,client_secret):
    encoded = base64.b64encode(bytes(client_id+':'+client_secret,'utf-8'))
    params = {'grant_type':'client_credentials'}
    header = {'Authorization': 'Basic'+str(encoded,'utf-8')}
    r = requests.post('https://accounts.spotify.com/api/token',data=params, headers=header)
    if r.status_code!=200:
        print('Error en la request.',r.json())
        return None
    print('token valido por {} segundos'.format(r.json()['expires_in']))
    return r.json()['access_token']

# %%
epAlbums='/artists/{ArtistId}/albums'
token = get_token('',' ')
# Out:
# Error en la request. {'error': 'invalid_client'}

# %%
params = {'country':'AR'}
header = {'Authorization':'Bearer {}'.format(token)}

# %%
albumsArtist=requests.get(urlBase+epAlbums.format(ArtistId=idArtist),headers=header,params=params)

# %%
print(albumsArtist.status_code)
albumsArtist.json()
# Out:
# 200
# {'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ/albums?offset=0&limit=20&include_groups=album,single,compilation,appears_on&market=AR',
#  'items': [{'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#      'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#      'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#      'name': 'The Weeknd',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6YlDIxqEjvY63ffH6AwCjd'},
#    'href': 'https://api.spotify.com/v1/albums/6YlDIxqEjvY63ffH6AwCjd',
#    'id': '6YlDIxqEjvY63ffH6AwCjd',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27380880b62143e819e901d8465',
#      'width': 640},
#     {'height': 300,
# ...

# %%
albumsDf = pd.DataFrame(albumsArtist.json()['items'])
albumsDf
# Out:
#    album_group album_type                                            artists  \
# 0        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 1        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 2        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 3        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 4        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 5        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 6        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 7        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 8        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 9        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 10      single     single  [{'external_urls': {'spotify': 'https://open.s...
# ...

# %%
def obtener_tracks(album_id, token, return_name=False, page_limit=50, market=None):
"""Función que devuelve una lista con los tracks de un album determinado"""

    url = f'https://api.spotify.com/v1/albums/{album_id}/tracks'
    header = {'Authorization': f'Bearer {token}'}
    params = {
        'limit': page_limit,
        'offset': 0,
        'market':market
    }
    lista = []
    r = requests.get(url, params=params, headers=header)
    if r.status_code != 200:
        print('Error en la request.', r.json())
        return None
    if return_name:
        lista += [(item['id'], item['name']) for item in r.json()['items']]
    else:
        lista += [item['id'] for item in r.json()['items']]
        
    while r.json()['next']:
        r = requests.get(r.json()['next'], headers=header)
        if r.status_code == 200:
            if return_name:
                lista += [(item['id'], item['name']) for item in r.json()['items']]
            else:
                lista += [item['id'] for item in r.json()['items']]
        else:
            print('Error:', r.status_code, '\n', r.json())
    return lista
